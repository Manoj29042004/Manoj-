# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('country_wise_latest.csv')

# %%
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.isna().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.impute import SimpleImputer

# %%
def null_to_zero():
    c=input("enter the column you want to replace null values with '0':")
    y = df[c].count()+df[c].isna().sum()
    x = np.reshape(df[c].values,(y,1))
    imputer = SimpleImputer(missing_values=np.nan,strategy='constant',fill_value=0)
    imputer.fit(x)
    df[c]=imputer.transform(x)

# %%
df = pd.read_csv('Data.csv',header=None)

# %%
df= pd.DataFrame(df.values,columns=['Name','eng','hin','mth','sic'])

# %%
df
# Out:
#        Name   eng   hin   mth   sic
# 0    Ashish  45.0  65.0  76.0  78.0
# 1       Raj  65.0  45.0  65.0  76.0
# 2    Rohini  65.0  67.0   6.0  55.0
# 3    Rakesh  65.0  66.0  77.0  88.0
# 4    Rajesh  88.0  77.0  87.0  89.0
# 5    Manish  65.0  45.0  45.0  45.0
# 6     Manoj   NaN  66.0  88.0  56.0
# 7     Suraj  55.0   NaN  76.0  87.0
# 8     Sumit  66.0  77.0   NaN  89.0
# 9    Ratish  66.0  55.0  66.0   NaN
# 10  Tanisha  77.0  66.0  56.0  87.0
# 11      NaN  98.0  89.0  98.0  88.0
# 12      NaN  22.0  23.0  34.0  32.0

# %%
null_to_zero()
# Out:
# enter the column you want to replace null values with '0':eng

# %%
null_to_zero()
# Out:
# enter the column you want to replace null values with '0':Name

# %%
df
# Out:
#        Name   eng   hin   mth   sic
# 0    Ashish  45.0  65.0  76.0  78.0
# 1       Raj  65.0  45.0  65.0  76.0
# 2    Rohini  65.0  67.0   6.0  55.0
# 3    Rakesh  65.0  66.0  77.0  88.0
# 4    Rajesh  88.0  77.0  87.0  89.0
# 5    Manish  65.0  45.0  45.0  45.0
# 6     Manoj     0  66.0  88.0  56.0
# 7     Suraj  55.0   NaN  76.0  87.0
# 8     Sumit  66.0  77.0   NaN  89.0
# 9    Ratish  66.0  55.0  66.0   NaN
# 10  Tanisha  77.0  66.0  56.0  87.0
# 11        0  98.0  89.0  98.0  88.0
# 12        0  22.0  23.0  34.0  32.0
